# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as npr

# %%
dataset = ['BAC']
for datasets in dataset :
    Ticker = yf.Ticker(datasets)
    data = Ticker.history(start='2023-09-01', end='2023-10-13')
    filename=f'{dataset}_data.csv'
    data.to_csv(filename)
    print(f'Download data for {dataset} and saved as {filename}')
# Out:
# Download data for ['BAC'] and saved as ['BAC']_data.csv

# %%
data_start = '2023-09-01'
data_end= '2023-10-13'
Ticker = 'BAC'
data = yf.download(Ticker, start=data_start, end=data_end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
sample_size = 500
rn1 = npr.rand(sample_size, 3)
rn2 = npr.randint(0, 10, sample_size)
rn3 = npr.sample(size=sample_size)
a= [0, 25, 50, 75, 100]
rn4 = npr.choice(a, size=sample_size)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(7,7))

ax1.hist(rn1, bins=25, stacked=True)
ax1.set_title('rand')
ax1.set_ylabel('frequency')
ax1.grid(True)
ax2.hist(rn2, bins=25)
ax2.set_title('randint')
ax2.grid(True)
ax3.hist(rn3, bins=25)
ax3.set_title('Sample')
ax3.set_ylabel('frequency')
ax3.grid(True)
ax4.hist(rn4, bins=25)
ax4.set_title('choice')
ax4.grid(True)

# %%
sample_size = 500
rn1 = npr.standard_normal(sample_size)
rn2 = npr.normal(100, 20, sample_size)
rn3 = npr.chisquare(df=0.5, size=sample_size)
rn4 = npr.poisson(lam=1.0, size=sample_size)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(7,7))
ax1.hist(rn1, bins=25)
ax1.set_title('standard normal')
ax1.set_ylabel('frequency')
ax1.grid(True)
ax2.hist(rn2, bins=25)
ax2.set_title('normal(100, 20)')
ax2.grid(True)
ax3.hist(rn3, bins=25)
ax3.set_title('chi-Sqaure')
ax3.grid(True)
ax4.hist(rn4, bins=25)
ax4.set_title('Poisson')
ax4.grid(True)

# %% [markdown]
# # **Simulations**

# %%
data.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-10-06  25.770000  26.230000  25.469999  26.070000  26.070000  58120700
# 2023-10-09  25.760000  26.360001  25.719999  26.309999  26.309999  39953700
# 2023-10-10  26.610001  27.299999  26.570000  27.010000  27.010000  51960100
# 2023-10-11  27.170000  27.440001  26.900000  27.020000  27.020000  38508200
# 2023-10-12  26.969999  27.080000  26.610001  26.900000  26.900000  44249800

# %%
S0 = 26.90
r = 0.054
sigma = 0.24
T = 3/12
I =10000
ST1 = S0 * np.exp((r - 0.5 * sigma ** 2) * T + sigma * np.sqrt(T) * npr.standard_normal(I))

# %%
plt.hist(ST1, bins=500)
plt.xlabel('index level')
plt.ylabel('frequency')
plt.grid(True)

# %%
I = 1000
M = 50
dt = T / M
s = np.zeros((M + 1, I))
s[0] = S0
for t in range (1,   M + 1 ):
    s[t] = s[t - 1] * np.exp((r - 0.5 * sigma ** 2) * dt
              + sigma * np.sqrt(dt) * npr.standard_normal(I))

# %%
plt.hist(s[-1], bins=50)
plt.xlabel('index Levels')
plt.ylabel('frequency')
plt.grid(True)

# %% [markdown]
# # **Random Number**

# %%
npr.rand(10)
# Out:
# array([7.57696073e-01, 4.02410840e-01, 2.29637591e-01, 6.49052976e-01,
#        3.93959245e-04, 5.27611169e-01, 3.06764067e-01, 3.62679570e-01,
#        5.89122218e-01, 9.05900780e-01])

# %%
npr.rand(5, 5)
# Out:
# array([[0.58979959, 0.01823132, 0.84115179, 0.54289796, 0.17926988],
#        [0.03676414, 0.2452965 , 0.60945318, 0.49337092, 0.50235444],
#        [0.67409394, 0.09320639, 0.72332965, 0.8036345 , 0.00980807],
#        [0.37315967, 0.60081735, 0.23265144, 0.66141988, 0.79712801],
#        [0.82484424, 0.70128343, 0.40695033, 0.17356964, 0.64461418]])

# %%
a = 7
b = 12
npr.rand(10) * (b-a) + a
# Out:
# array([ 9.85170911,  8.34280366, 11.10227425,  9.95995632, 10.84248963,
#         9.72941382,  8.56172547,  9.54655726,  7.05674426, 10.9606143 ])

# %%
npr.rand(5, 5) * (b-a) +a
# Out:
# array([[ 8.8567284 ,  8.78542924, 11.78258291,  7.39301866, 10.86308692],
#        [ 9.67932273,  7.96147442,  7.82668955, 10.96973094,  8.17750438],
#        [ 7.27271721,  9.55060422,  9.984305  ,  9.77261642,  7.97304909],
#        [ 9.20698347,  8.03992831,  7.9444251 , 11.71468168, 10.36858664],
#        [ 9.97316397, 10.49771324, 11.15421291, 10.09161291,  9.96398561]])

# %%
ST2 = S0 * npr.lognormal((r - 0.5 * sigma ** 2)* T,
                         sigma * np.sqrt(T), size=I)

# %%
plt.hist(ST2, bins=50)
plt.xlabel('index levels')
plt.ylabel('frequency')
plt.grid(True)
