# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
symbols = ['GS', 'TSLA', 'BLK', 'AAPL']
start = '2024-01-01'
end = '2024-02-29'

# %%
data = pd.DataFrame()
for sym in symbols:
    data[sym] = yf.download(sym, start, end)['Adj Close']
data.dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                     GS        TSLA         BLK        AAPL
# Date
# 2024-01-02  388.299988  248.419998  800.299988  185.403412
# 2024-01-03  381.790009  238.449997  784.150024  184.015198
# 2024-01-04  382.950012  237.929993  785.950012  181.678177
# 2024-01-05  386.440002  237.490005  782.830017  180.949097
# 2024-01-08  388.859985  240.449997  797.190002  185.323517
# 2024-01-09  383.739990  234.960007  794.520020  184.904053
# 2024-01-10  381.959991  233.940002  792.359985  185.952713
# 2024-01-11  379.750000  227.220001  792.609985  185.353485
# 2024-01-12  377.750000  218.889999  799.599976  185.683060
# 2024-01-16  380.450012  219.910004  791.380005  183.395981
# 2024-01-17  377.179993  215.550003  787.429993  182.447189
# 2024-01-18  376.910004  211.880005  795.260010  188.389618
# 2024-01-19  382.200012  212.190002  805.440002  191.315872
# 2024-01-22  385.959991  208.800003  794.020020  193.642899
# 2024-01-23  380.769989  209.139999  792.559998  194.931259
# 2024-01-24  379.399994  207.830002  785.750000  194.252121
# 2024-01-25  382.700012  182.630005  790.460022  193.922546
# 2024-01-26  377.790009  183.250000  787.299988  192.174774
# 2024-01-29  380.559998  190.929993  788.700012  191.485657
# 2024-01-30  386.869995  191.589996  781.729980  187.800354
# 2024-01-31  384.010010  187.289993  774.309998  184.164993
# 2024-02-01  383.850006  188.860001  784.929993  186.621872
# 2024-02-02  387.859985  187.910004  788.000000  185.613159
# 2024-02-05  383.019989  181.059998  783.169983  187.440811
# 2024-02-06  384.989990  185.100006  787.979980  189.058762
# 2024-02-07  386.660004  187.580002  794.700012  189.168625
# 2024-02-08  385.040009  189.559998  793.200012  188.080017
# 2024-02-09  384.260010  193.570007  797.210022  188.850006
# 2024-02-12  392.640015  188.130005  801.760010  187.149994
# 2024-02-13  378.750000  184.020004  778.070007  185.039993
# 2024-02-14  378.040009  188.710007  785.400024  184.149994
# 2024-02-15  385.420013  200.449997  798.049988  183.860001
# 2024-02-16  384.440002  199.949997  794.000000  182.309998
# 2024-02-20  384.519989  193.759995  798.109985  181.559998

# %%
rets = np.log(data / data.shift(1))

# %%
rets
# Out:
#                   GS      TSLA       BLK      AAPL
# Date
# 2024-01-02       NaN       NaN       NaN       NaN
# 2024-01-03 -0.016907 -0.040961 -0.020386 -0.007516
# 2024-01-04  0.003034 -0.002183  0.002293 -0.012781
# 2024-01-05  0.009072 -0.001851 -0.003978 -0.004021
# 2024-01-08  0.006243  0.012387  0.018177  0.023887
# 2024-01-09 -0.013254 -0.023097 -0.003355 -0.002266
# 2024-01-10 -0.004649 -0.004351 -0.002722  0.005655
# 2024-01-11 -0.005803 -0.029146  0.000315 -0.003228
# 2024-01-12 -0.005281 -0.037349  0.008780  0.001777
# 2024-01-16  0.007122  0.004649 -0.010333 -0.012394
# 2024-01-17 -0.008632 -0.020025 -0.005004 -0.005187
# 2024-01-18 -0.000716 -0.017173  0.009895  0.032051
# 2024-01-19  0.013938  0.001462  0.012720  0.015414
# 2024-01-22  0.009790 -0.016105 -0.014280  0.012090
# 2024-01-23 -0.013538  0.001627 -0.001840  0.006631
# 2024-01-24 -0.003604 -0.006283 -0.008630 -0.003490
# 2024-01-25  0.008660 -0.129258  0.005976 -0.001698
# 2024-01-26 -0.012913  0.003389 -0.004006 -0.009054
# 2024-01-29  0.007305  0.041055  0.001777 -0.003592
# 2024-01-30  0.016445  0.003451 -0.008877 -0.019433
# 2024-01-31 -0.007420 -0.022699 -0.009537 -0.019547
# 2024-02-01 -0.000417  0.008348  0.013622  0.013252
# 2024-02-02  0.010393 -0.005043  0.003904 -0.005420
# 2024-02-05 -0.012557 -0.037135 -0.006148  0.009798
# 2024-02-06  0.005130  0.022068  0.006123  0.008595
# 2024-02-07  0.004328  0.013309  0.008492  0.000581
# 2024-02-08 -0.004199  0.010500 -0.001889 -0.005771
# 2024-02-09 -0.002028  0.020934  0.005043  0.004086
# 2024-02-12  0.021574 -0.028506  0.005691 -0.009043
# 2024-02-13 -0.036017 -0.022089 -0.029993 -0.011338
# 2024-02-14 -0.001876  0.025167  0.009377 -0.004821
# 2024-02-15  0.019334  0.060353  0.015978 -0.001576
# 2024-02-16 -0.002546 -0.002498 -0.005088 -0.008466
# 2024-02-20  0.000208 -0.031447  0.005163 -0.004122

# %%
rets.dropna()
# Out:
#                   GS      TSLA       BLK      AAPL
# Date
# 2024-01-03 -0.016907 -0.040961 -0.020386 -0.007516
# 2024-01-04  0.003034 -0.002183  0.002293 -0.012781
# 2024-01-05  0.009072 -0.001851 -0.003978 -0.004021
# 2024-01-08  0.006243  0.012387  0.018177  0.023887
# 2024-01-09 -0.013254 -0.023097 -0.003355 -0.002266
# 2024-01-10 -0.004649 -0.004351 -0.002722  0.005655
# 2024-01-11 -0.005803 -0.029146  0.000315 -0.003228
# 2024-01-12 -0.005281 -0.037349  0.008780  0.001777
# 2024-01-16  0.007122  0.004649 -0.010333 -0.012394
# 2024-01-17 -0.008632 -0.020025 -0.005004 -0.005187
# 2024-01-18 -0.000716 -0.017173  0.009895  0.032051
# 2024-01-19  0.013938  0.001462  0.012720  0.015414
# 2024-01-22  0.009790 -0.016105 -0.014280  0.012090
# 2024-01-23 -0.013538  0.001627 -0.001840  0.006631
# 2024-01-24 -0.003604 -0.006283 -0.008630 -0.003490
# 2024-01-25  0.008660 -0.129258  0.005976 -0.001698
# 2024-01-26 -0.012913  0.003389 -0.004006 -0.009054
# 2024-01-29  0.007305  0.041055  0.001777 -0.003592
# 2024-01-30  0.016445  0.003451 -0.008877 -0.019433
# 2024-01-31 -0.007420 -0.022699 -0.009537 -0.019547
# 2024-02-01 -0.000417  0.008348  0.013622  0.013252
# 2024-02-02  0.010393 -0.005043  0.003904 -0.005420
# 2024-02-05 -0.012557 -0.037135 -0.006148  0.009798
# 2024-02-06  0.005130  0.022068  0.006123  0.008595
# 2024-02-07  0.004328  0.013309  0.008492  0.000581
# 2024-02-08 -0.004199  0.010500 -0.001889 -0.005771
# 2024-02-09 -0.002028  0.020934  0.005043  0.004086
# 2024-02-12  0.021574 -0.028506  0.005691 -0.009043
# 2024-02-13 -0.036017 -0.022089 -0.029993 -0.011338
# 2024-02-14 -0.001876  0.025167  0.009377 -0.004821
# 2024-02-15  0.019334  0.060353  0.015978 -0.001576
# 2024-02-16 -0.002546 -0.002498 -0.005088 -0.008466
# 2024-02-20  0.000208 -0.031447  0.005163 -0.004122

# %%
lags = 7

# %%
def add_lags(data, ric, lags):
    cols = []
    df = pd.DataFrame(data[ric])
    for lag in range(1, lags + 1 ):
        col = 'lag_{}'.format(lag)
        df[col] = df[ric].shift(lag)
        cols.append(col)
    df.dropna(inplace=True)
    return df, cols

# %%
dfs = {}
for sym in data.columns:
    df, cols = add_lags(data, sym, lags)
    dfs[sym] = df

# %%
dfs[sym].head(7)
# Out:
#                   AAPL       lag_1       lag_2       lag_3       lag_4  \
# Date
# 2024-01-11  185.353485  185.952713  184.904053  185.323517  180.949097
# 2024-01-12  185.683060  185.353485  185.952713  184.904053  185.323517
# 2024-01-16  183.395981  185.683060  185.353485  185.952713  184.904053
# 2024-01-17  182.447189  183.395981  185.683060  185.353485  185.952713
# 2024-01-18  188.389618  182.447189  183.395981  185.683060  185.353485
# 2024-01-19  191.315872  188.389618  182.447189  183.395981  185.683060
# 2024-01-22  193.642899  191.315872  188.389618  182.447189  183.395981
#
#                  lag_5       lag_6       lag_7
# Date
# 2024-01-11  181.678177  184.015198  185.403412
# 2024-01-12  180.949097  181.678177  184.015198
# 2024-01-16  185.323517  180.949097  181.678177
# 2024-01-17  184.904053  185.323517  180.949097
# 2024-01-18  185.952713  184.904053  185.323517
# 2024-01-19  185.353485  185.952713  184.904053
# 2024-01-22  185.683060  185.353485  185.952713

# %%
regs = {}
for sym in data.columns:
    df = dfs[sym]
    reg = np.linalg.lstsq(df[cols], df[sym], rcond=-1)[0]
    regs[sym] = reg

# %%
rega = np.stack(tuple(regs.values()))

# %%
regd = pd.DataFrame(rega, columns=cols, index=data.columns)

# %%
regd
# Out:
#          lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7
# GS    0.620336 -0.032548  0.322981 -0.169813 -0.171781  0.703796 -0.272465
# TSLA  1.082889 -0.483630  0.473354 -0.151350  0.175926  0.099324 -0.204265
# BLK   0.660329 -0.220289  0.411701  0.025717 -0.037851  0.353361 -0.192565
# AAPL  1.215461 -0.201840  0.018068 -0.199680  0.027487  0.015151  0.124830

# %%
regd.mean().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: >

# %%
dfs[sym].corr()
# Out:
#            AAPL     lag_1     lag_2     lag_3     lag_4     lag_5     lag_6  \
# AAPL   1.000000  0.851380  0.600925  0.321181  0.046392 -0.130869 -0.197891
# lag_1  0.851380  1.000000  0.837184  0.578849  0.290289  0.030551 -0.126353
# lag_2  0.600925  0.837184  1.000000  0.832068  0.567818  0.295840  0.052394
# lag_3  0.321181  0.578849  0.832068  1.000000  0.811969  0.567381  0.315790
# lag_4  0.046392  0.290289  0.567818  0.811969  1.000000  0.828091  0.592454
# lag_5 -0.130869  0.030551  0.295840  0.567381  0.828091  1.000000  0.835558
# lag_6 -0.197891 -0.126353  0.052394  0.315790  0.592454  0.835558  1.000000
# lag_7 -0.173781 -0.175858 -0.093497  0.082855  0.351159  0.609333  0.840034
#
#           lag_7
# AAPL  -0.173781
# lag_1 -0.175858
# lag_2 -0.093497
# lag_3  0.082855
# lag_4  0.351159
# lag_5  0.609333
# lag_6  0.840034
# lag_7  1.000000

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(data[sym].dropna())
# Out:
# (-1.9167684064529307,
#  0.32421430487062797,
#  1,
#  32,
#  {'1%': -3.653519805908203,
#   '5%': -2.9572185644531253,
#   '10%': -2.6175881640625},
#  100.48647553163977)

# %%
ret_ = np.log(data / data.shift(1))

# %%
ret_.dropna(inplace=True)

# %%
ret_
# Out:
#                   GS      TSLA       BLK      AAPL
# Date
# 2024-01-03 -0.016907 -0.040961 -0.020386 -0.007516
# 2024-01-04  0.003034 -0.002183  0.002293 -0.012781
# 2024-01-05  0.009072 -0.001851 -0.003978 -0.004021
# 2024-01-08  0.006243  0.012387  0.018177  0.023887
# 2024-01-09 -0.013254 -0.023097 -0.003355 -0.002266
# 2024-01-10 -0.004649 -0.004351 -0.002722  0.005655
# 2024-01-11 -0.005803 -0.029146  0.000315 -0.003228
# 2024-01-12 -0.005281 -0.037349  0.008780  0.001777
# 2024-01-16  0.007122  0.004649 -0.010333 -0.012394
# 2024-01-17 -0.008632 -0.020025 -0.005004 -0.005187
# 2024-01-18 -0.000716 -0.017173  0.009895  0.032051
# 2024-01-19  0.013938  0.001462  0.012720  0.015414
# 2024-01-22  0.009790 -0.016105 -0.014280  0.012090
# 2024-01-23 -0.013538  0.001627 -0.001840  0.006631
# 2024-01-24 -0.003604 -0.006283 -0.008630 -0.003490
# 2024-01-25  0.008660 -0.129258  0.005976 -0.001698
# 2024-01-26 -0.012913  0.003389 -0.004006 -0.009054
# 2024-01-29  0.007305  0.041055  0.001777 -0.003592
# 2024-01-30  0.016445  0.003451 -0.008877 -0.019433
# 2024-01-31 -0.007420 -0.022699 -0.009537 -0.019547
# 2024-02-01 -0.000417  0.008348  0.013622  0.013252
# 2024-02-02  0.010393 -0.005043  0.003904 -0.005420
# 2024-02-05 -0.012557 -0.037135 -0.006148  0.009798
# 2024-02-06  0.005130  0.022068  0.006123  0.008595
# 2024-02-07  0.004328  0.013309  0.008492  0.000581
# 2024-02-08 -0.004199  0.010500 -0.001889 -0.005771
# 2024-02-09 -0.002028  0.020934  0.005043  0.004086
# 2024-02-12  0.021574 -0.028506  0.005691 -0.009043
# 2024-02-13 -0.036017 -0.022089 -0.029993 -0.011338
# 2024-02-14 -0.001876  0.025167  0.009377 -0.004821
# 2024-02-15  0.019334  0.060353  0.015978 -0.001576
# 2024-02-16 -0.002546 -0.002498 -0.005088 -0.008466
# 2024-02-20  0.000208 -0.031447  0.005163 -0.004122

# %%
dfs = {}
for sym in data:
    df, cols = add_lags(ret_, sym, lags)
    mu, std = df[cols].mean(), df[cols].std()
    df[cols] = (df[cols] - mu) / std
    dfs[sym] = df

# %%
dfs[sym].head()
# Out:
#                 AAPL     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2024-01-12  0.001777 -0.216794  0.518242 -0.178325  1.881980 -0.429259
# 2024-01-16 -0.012394  0.223004 -0.265591  0.520395 -0.255468  1.891353
# 2024-01-17 -0.005187 -1.022349  0.175975 -0.263154  0.391925 -0.283318
# 2024-01-18  0.032051 -0.388981 -1.074385  0.178252 -0.334065  0.375349
# 2024-01-19  0.015414  2.883751 -0.438470 -1.071654  0.074916 -0.363284
#
#                lag_6     lag_7
# Date
# 2024-01-12 -1.131800 -0.657515
# 2024-01-16 -0.412226 -1.086712
# 2024-01-17  1.880159 -0.372681
# 2024-01-18 -0.268060  1.902042
# 2024-01-19  0.382595 -0.229626

# %%
adfuller(dfs[sym]['lag_1'])
# Out:
# (-2.8069100414732873,
#  0.05729347701409013,
#  9,
#  16,
#  {'1%': -3.9240193847656246, '5%': -3.0684982031250003, '10%': -2.67389265625},
#  23.8084274415816)

# %%
dfs[sym].corr()
# Out:
#            AAPL     lag_1     lag_2     lag_3     lag_4     lag_5     lag_6  \
# AAPL   1.000000  0.293229  0.088041  0.051921 -0.198423 -0.274465 -0.236677
# lag_1  0.293229  1.000000  0.281700  0.088231  0.026622 -0.210507 -0.271312
# lag_2  0.088041  0.281700  1.000000  0.275497  0.112071 -0.010748 -0.256842
# lag_3  0.051921  0.088231  0.275497  1.000000  0.239341  0.112111 -0.006386
# lag_4 -0.198423  0.026622  0.112071  0.239341  1.000000  0.176231  0.000986
# lag_5 -0.274465 -0.210507 -0.010748  0.112111  0.176231  1.000000  0.162034
# lag_6 -0.236677 -0.271312 -0.256842 -0.006386  0.000986  0.162034  1.000000
# lag_7  0.088190 -0.226050 -0.277360 -0.248639 -0.053432  0.023357  0.198546
#
#           lag_7
# AAPL   0.088190
# lag_1 -0.226050
# lag_2 -0.277360
# lag_3 -0.248639
# lag_4 -0.053432
# lag_5  0.023357
# lag_6  0.198546
# lag_7  1.000000

# %%
from sklearn.metrics import accuracy_score

# %%
# %%time
for sym in data:
    df = dfs[sym]
    reg = np.linalg.lstsq(df[cols], df[sym], rcond=-1)[0]
    pred = np.dot(df[cols], reg)
    acc = accuracy_score(np.sign(df[sym]), np.sign(pred))
    print(f'OLS | {sym:10s} | acc={acc:.4f}')
# Out:
# OLS | GS         | acc=0.6923
# OLS | TSLA       | acc=0.6538
# OLS | BLK        | acc=0.6923
# OLS | AAPL       | acc=0.6923
# CPU times: user 16.8 ms, sys: 977 µs, total: 17.7 ms
# Wall time: 19 ms

# %%
from sklearn.neural_network import MLPRegressor

# %%
# %%time
for sym in data.columns:
    df = dfs[sym]
    model = MLPRegressor(hidden_layer_sizes=[512],
                         random_state=100,
                         max_iter=1000,
                         early_stopping=True,
                         validation_fraction=0.15,
                         shuffle=False)
    model.fit(df[cols], df[sym])
    pred = model.predict(df[cols])
    acc = accuracy_score(np.sign(df[sym]), np.sign(pred))
    print(f'MLP | {sym:10s} | acc={acc:.4f}')
# Out:
# MLP | GS         | acc=0.6154
# MLP | TSLA       | acc=0.4231
# MLP | BLK        | acc=0.7308
# MLP | AAPL       | acc=0.5000
# CPU times: user 133 ms, sys: 117 ms, total: 250 ms
# Wall time: 134 ms
# MLP | GS         | acc=0.6154
# MLP | TSLA       | acc=0.4231
# MLP | BLK        | acc=0.7308
# MLP | AAPL       | acc=0.5000
# CPU times: user 144 ms, sys: 103 ms, total: 247 ms
# Wall time: 134 ms

# %%
import tensorflow as tf
from keras.layers import Dense
from keras.models import Sequential

# %%
np.random.seed(100)
tf.random.set_seed(100)

# %%
def create_model(problem='regression'):
    model = Sequential()
    model.add(Dense(512, input_dim=len(cols),
                    activation='relu'))
    if problem =='regression':
        model.add(Dense(1, activation='linear'))
        model.compile(loss='mse', optimizer='adam')
    else :
        model.add(Dense(1, activations='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer='adam')
    return model

# %%
# %%time
for sym in data.columns [:]:
    df = dfs[sym]
    model = create_model()
    model.fit(df[cols], df[sym], epochs=25,verbose=False)
    pred = model.predict(df[cols])
    acc = accuracy_score(np.sign(df[sym]), np.sign(pred))
    print(f'DNN | {sym:10s} | acc={acc:.4f}')
# Out:
# 1/1 [==============================] - 0s 125ms/step
# DNN | GS         | acc=0.8077
# 1/1 [==============================] - 0s 47ms/step
# DNN | TSLA       | acc=0.9231
# 1/1 [==============================] - 0s 50ms/step
# DNN | BLK        | acc=0.5769
# 1/1 [==============================] - 0s 48ms/step
# DNN | AAPL       | acc=0.6538
# CPU times: user 3.84 s, sys: 80.2 ms, total: 3.92 s
# Wall time: 4.13 s

# %%
split = int(len(dfs[sym]) * 0.8)

# %%
# %%time
for sym in data.columns:
    df = dfs[sym]
    train = df.iloc[:split]
    reg =  np.linalg.lstsq(train[cols], train[sym], rcond=-1)[0]
    test = df.iloc[split:]
    pred = np.dot(test[cols], reg)
    acc = accuracy_score(np.sign(test[sym]), np.sign(pred))
    print(f'OLS | {sym:10s} | acc={acc:.4f}')
# Out:
# OLS | GS         | acc=0.8333
# OLS | TSLA       | acc=0.6667
# OLS | BLK        | acc=0.8333
# OLS | AAPL       | acc=0.3333
# CPU times: user 21.3 ms, sys: 0 ns, total: 21.3 ms
# Wall time: 29 ms

# %%
# %%time
for sym in data.columns:
    df = dfs[sym]
    train = df.iloc[:split]
    model = MLPRegressor(hidden_layer_sizes=[512],
                         random_state=100,
                         max_iter=1000,
                         early_stopping=True,
                         validation_fraction=0.15,
                         shuffle=False)
    model.fit(train[cols], train[sym])
    test = df.iloc[:split]
    pred = model.predict(test[cols])
    acc = accuracy_score(np.sign(test[sym]), np.sign(pred))
    print(f'MLP| {sym:.10s}| acc={acc:.4f}')
# Out:
# MLP| GS| acc=0.7000
# MLP| TSLA| acc=0.5500
# MLP| BLK| acc=0.5000
# MLP| AAPL| acc=0.5500
# CPU times: user 137 ms, sys: 71.5 ms, total: 208 ms
# Wall time: 122 ms

# %%
# %%time
for sym in data.columns:
    df = dfs[sym]
    train = df.iloc[:split]
    model = create_model()
    model.fit(train[cols], train[sym], epochs=50, verbose=True)
    test = df.iloc[split:]
    pred = model.predict(test[cols])
    acc = accuracy_score(np.sign(test[sym]), np.sign(pred))
    print(f'DNN| {sym:10s}: acc={acc:.4f}')
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 510ms/step - loss: 0.0266
# Epoch 2/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0123
# Epoch 3/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0057
# Epoch 4/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 5/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 6/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 7/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 8/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 9/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 10/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 13/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 14/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 15/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 16/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 17/50
# 1/1 [==============================] - 0s 8ms/step - loss: 8.0441e-04
# Epoch 18/50
# 1/1 [==============================] - 0s 12ms/step - loss: 7.8406e-04
# Epoch 19/50
# 1/1 [==============================] - 0s 14ms/step - loss: 8.3309e-04
# Epoch 20/50
# 1/1 [==============================] - 0s 11ms/step - loss: 8.4067e-04
# Epoch 21/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.6237e-04
# Epoch 22/50
# 1/1 [==============================] - 0s 15ms/step - loss: 6.3074e-04
# Epoch 23/50
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1533e-04
# Epoch 24/50
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7222e-04
# Epoch 25/50
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0937e-04
# Epoch 26/50
# 1/1 [==============================] - 0s 11ms/step - loss: 5.8297e-04
# Epoch 27/50
# 1/1 [==============================] - 0s 14ms/step - loss: 6.2531e-04
# Epoch 28/50
# 1/1 [==============================] - 0s 8ms/step - loss: 5.8796e-04
# Epoch 29/50
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6937e-04
# Epoch 30/50
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1154e-04
# Epoch 31/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7263e-04
# Epoch 32/50
# 1/1 [==============================] - 0s 16ms/step - loss: 9.4797e-05
# Epoch 33/50
# 1/1 [==============================] - 0s 12ms/step - loss: 8.4975e-05
# Epoch 34/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1867e-04
# Epoch 35/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6056e-04
# Epoch 36/50
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8623e-04
# Epoch 37/50
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9141e-04
# Epoch 38/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8497e-04
# Epoch 39/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7559e-04
# Epoch 40/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6322e-04
# Epoch 41/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4139e-04
# Epoch 42/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0631e-04
# Epoch 43/50
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3928e-05
# Epoch 44/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8298e-05
# Epoch 45/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2837e-05
# Epoch 46/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1125e-05
# Epoch 47/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4364e-05
# Epoch 48/50
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7138e-05
# Epoch 49/50
# 1/1 [==============================] - 0s 8ms/step - loss: 7.6919e-05
# Epoch 50/50
# 1/1 [==============================] - 0s 8ms/step - loss: 7.0603e-05
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x783271639f30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 84ms/step
# DNN| GS        : acc=0.6667
# Epoch 1/50
# 1/1 [==============================] - 1s 681ms/step - loss: 0.0281
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0134
# Epoch 3/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0059
# Epoch 4/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 5/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 7/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0042
# Epoch 8/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0052
# Epoch 9/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0053
# Epoch 10/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 11/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 12/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 13/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 14/50
# 1/1 [==============================] - 0s 12ms/step - loss: 7.5097e-04
# Epoch 15/50
# 1/1 [==============================] - 0s 11ms/step - loss: 5.4974e-04
# Epoch 16/50
# 1/1 [==============================] - 0s 10ms/step - loss: 6.7365e-04
# Epoch 17/50
# 1/1 [==============================] - 0s 10ms/step - loss: 9.6957e-04
# Epoch 18/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 20/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 21/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 22/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 23/50
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4537e-04
# Epoch 24/50
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7308e-04
# Epoch 25/50
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8582e-04
# Epoch 26/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1315e-04
# Epoch 27/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5016e-04
# Epoch 28/50
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5524e-04
# Epoch 29/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6410e-04
# Epoch 30/50
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1874e-04
# Epoch 31/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9341e-04
# Epoch 32/50
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0074e-04
# Epoch 33/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7751e-04
# Epoch 34/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6409e-04
# Epoch 35/50
# 1/1 [==============================] - 0s 10ms/step - loss: 8.9239e-05
# Epoch 36/50
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3772e-05
# Epoch 37/50
# 1/1 [==============================] - 0s 10ms/step - loss: 8.0737e-05
# Epoch 38/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2037e-04
# Epoch 39/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5905e-04
# Epoch 40/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7878e-04
# Epoch 41/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7279e-04
# Epoch 42/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4482e-04
# Epoch 43/50
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0454e-04
# Epoch 44/50
# 1/1 [==============================] - 0s 10ms/step - loss: 6.3587e-05
# Epoch 45/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3175e-05
# Epoch 46/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1082e-05
# Epoch 47/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7737e-05
# Epoch 48/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5161e-05
# Epoch 49/50
# 1/1 [==============================] - 0s 9ms/step - loss: 6.1408e-05
# Epoch 50/50
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7795e-05
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x783271638940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 50ms/step
# DNN| TSLA      : acc=0.6667
# Epoch 1/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.0138
# Epoch 2/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0044
# Epoch 3/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 4/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 5/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 6/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0021
# Epoch 7/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 8/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 9/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 10/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 11/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 12/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 13/50
# 1/1 [==============================] - 0s 9ms/step - loss: 8.1368e-04
# Epoch 14/50
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2562e-04
# Epoch 15/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6081e-04
# Epoch 16/50
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3540e-04
# Epoch 17/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.2275e-04
# Epoch 18/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.4462e-04
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 5.9894e-04
# Epoch 20/50
# 1/1 [==============================] - 0s 14ms/step - loss: 4.1491e-04
# Epoch 21/50
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2192e-04
# Epoch 22/50
# 1/1 [==============================] - 0s 11ms/step - loss: 3.4871e-04
# Epoch 23/50
# 1/1 [==============================] - 0s 10ms/step - loss: 4.1759e-04
# Epoch 24/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2811e-04
# Epoch 25/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.4370e-04
# Epoch 26/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0942e-04
# Epoch 27/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0439e-04
# Epoch 28/50
# 1/1 [==============================] - 0s 9ms/step - loss: 8.0102e-05
# Epoch 29/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2931e-04
# Epoch 30/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0004e-04
# Epoch 31/50
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3622e-04
# Epoch 32/50
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1501e-04
# Epoch 33/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5594e-04
# Epoch 34/50
# 1/1 [==============================] - 0s 10ms/step - loss: 9.9397e-05
# Epoch 35/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.3566e-05
# Epoch 36/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.5413e-05
# Epoch 37/50
# 1/1 [==============================] - 0s 9ms/step - loss: 8.0490e-05
# Epoch 38/50
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9928e-05
# Epoch 39/50
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7716e-05
# Epoch 40/50
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2800e-05
# Epoch 41/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7292e-05
# Epoch 42/50
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4386e-05
# Epoch 43/50
# 1/1 [==============================] - 0s 9ms/step - loss: 6.6454e-05
# Epoch 44/50
# 1/1 [==============================] - 0s 12ms/step - loss: 6.2202e-05
# Epoch 45/50
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5003e-05
# Epoch 46/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7182e-05
# Epoch 47/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8590e-05
# Epoch 48/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9939e-05
# Epoch 49/50
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4530e-05
# Epoch 50/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5214e-05
# 1/1 [==============================] - 0s 52ms/step
# DNN| BLK       : acc=0.5000
# Epoch 1/50
# 1/1 [==============================] - 0s 483ms/step - loss: 0.0106
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 3/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0023
# Epoch 4/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 6/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 7/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9503e-04
# Epoch 9/50
# 1/1 [==============================] - 0s 8ms/step - loss: 7.2536e-04
# Epoch 10/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 13/50
# 1/1 [==============================] - 0s 9ms/step - loss: 9.8415e-04
# Epoch 14/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.3083e-04
# Epoch 15/50
# 1/1 [==============================] - 0s 9ms/step - loss: 5.6399e-04
# Epoch 16/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8347e-04
# Epoch 17/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4168e-04
# Epoch 18/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1703e-04
# Epoch 19/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1407e-04
# Epoch 20/50
# 1/1 [==============================] - 0s 13ms/step - loss: 4.2025e-04
# Epoch 21/50
# 1/1 [==============================] - 0s 9ms/step - loss: 4.0031e-04
# Epoch 22/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3493e-04
# Epoch 23/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4335e-04
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6632e-04
# Epoch 25/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3643e-04
# Epoch 26/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5818e-04
# Epoch 27/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0487e-04
# Epoch 28/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3477e-04
# Epoch 29/50
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1819e-04
# Epoch 30/50
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5782e-04
# Epoch 31/50
# 1/1 [==============================] - 0s 9ms/step - loss: 8.8175e-05
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0738e-05
# Epoch 33/50
# 1/1 [==============================] - 0s 9ms/step - loss: 6.0335e-05
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 9.4251e-05
# Epoch 35/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1570e-04
# Epoch 36/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0621e-04
# Epoch 37/50
# 1/1 [==============================] - 0s 9ms/step - loss: 7.5150e-05
# Epoch 38/50
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4335e-05
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9384e-05
# Epoch 40/50
# 1/1 [==============================] - 0s 9ms/step - loss: 3.2602e-05
# Epoch 41/50
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5662e-05
# Epoch 42/50
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5607e-05
# Epoch 43/50
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2903e-05
# Epoch 44/50
# 1/1 [==============================] - 0s 10ms/step - loss: 3.8407e-05
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2278e-05
# Epoch 46/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4348e-05
# Epoch 47/50
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5907e-05
# Epoch 48/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1171e-05
# Epoch 49/50
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4445e-05
# Epoch 50/50
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3801e-05
# 1/1 [==============================] - 0s 50ms/step
# DNN| AAPL      : acc=0.5000
# CPU times: user 5.59 s, sys: 120 ms, total: 5.71 s
# Wall time: 7.64 s
